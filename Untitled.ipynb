# %%
import pyarrow
import pandas as pd
import pathlib
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dfs = []
for year in range(2006, 2026):
    file_path = Path("data") / "pbp" / f"play_by_play_{year}.parquet"
    dfs.append(pd.read_parquet(file_path))

df = pd.concat(dfs, ignore_index=True)

# %%
df['score_differential'].value_counts().head(15)

fig, axes = plt.subplots(2, 3, figsize=(18, 10))

sns.countplot(data=df, x='down', ax=axes[0, 0], color='steelblue')
axes[0, 0].set_title('Distribution of Downs')
axes[0, 0].set_xlabel('Down')
axes[0, 0].set_ylabel('Count')

sns.histplot(df['ydstogo'], ax=axes[0, 1], color='seagreen')
axes[0, 1].set_title('Yards to Go')
axes[0, 1].set_xlabel('Yards to Go')
axes[0, 1].set_ylabel('Count')
top_ytg = df['ydstogo'].value_counts().head(5)
for x_val, count in top_ytg.items():
    axes[0, 1].text(int(x_val), count, str(int(x_val)),
                    ha='center', va='bottom', fontsize=9, fontweight='bold')

sns.histplot(df['yardline_100'], bins=100, ax=axes[0, 2], color='darkorange')
axes[0, 2].set_title('Field Position')
axes[0, 2].set_xlabel('Yards from Opponent End Zone')
axes[0, 2].set_ylabel('Count')
top_yard = df['yardline_100'].value_counts().head(7)
for x_val, count in top_yard.items():
    axes[0, 2].text(int(x_val), count, str(int(x_val)),
                    ha='center', va='bottom', fontsize=9, fontweight='bold')

sns.histplot(df['score_differential'], bins=100, ax=axes[1, 0], color='mediumpurple')
axes[1, 0].set_title('Score Differential')
axes[1, 0].set_xlabel('Score Differential')
axes[1, 0].set_ylabel('Count')
top_score = df['score_differential'].value_counts().head(10)
for x_val, count in top_score.items():
    axes[1, 0].text(int(x_val), count, str(int(x_val)),
                    ha='center', va='bottom', fontsize=9, fontweight='bold')

sns.histplot(df['game_seconds_remaining'], bins=60, ax=axes[1, 1], color='teal')
axes[1, 1].set_title('Game Seconds Remaining')
axes[1, 1].set_xlabel('Game Seconds Remaining')
axes[1, 1].set_ylabel('Count')
for boundary in [900, 1800, 2700]:
    axes[1, 1].axvline(boundary, color='red', linestyle='--', linewidth=1)

axes[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
def bin_down(d):
    return int(d)                       # 1, 2, 3, 4

def bin_ydstogo(y):
    y = int(y)
    return '10+' if y > 10 else str(y)  

YARDLINE_BINS = [
    ('1', 1, 1), ('2', 2, 2), ('3-5', 3, 5), ('6-10', 6, 10),
    ('11-14', 11, 14), ('15', 15, 15), ('16-20', 16, 20),
    ('21-25', 21, 25), ('26-29', 26, 29), ('30', 30, 30),
    ('31-34', 31, 34), ('35', 35, 35), ('36-40', 36, 40),
    ('41-45', 41, 45), ('46-50', 46, 50),
    ('51-55', 51, 55), ('56-60', 56, 60),
    ('61-65', 61, 65), ('66-70', 66, 70),
    ('71-74', 71, 74), ('75', 75, 75), ('76-79', 76, 79),
    ('80', 80, 80), ('81-85', 81, 85), ('86-90', 86, 90),
    ('91-95', 91, 95), ('96-99', 96, 99),
]

_yl_lookup = {v: label for label, lo, hi in YARDLINE_BINS for v in range(lo, hi + 1)}

def bin_yardline(y):
    return _yl_lookup[int(y)]

# %%
cols = ['game_id', 'down', 'ydstogo', 'yardline_100']
work = df[cols].dropna(subset=['down', 'ydstogo', 'yardline_100']).copy()

work['s_down'] = work['down'].map(bin_down)
work['s_ytg']  = work['ydstogo'].map(bin_ydstogo)
work['s_yl']   = work['yardline_100'].map(bin_yardline)

work['state'] = list(zip(work['s_down'], work['s_ytg'], work['s_yl']))

print(work['state'].nunique(), "number of states")
# Out:
# 945 number of states

# %%
work['next_state'] = work.groupby('game_id')['state'].shift(-1)
trans = work.dropna(subset=['next_state'])

states = sorted(set(work['state']))
state_idx = {s: i for i, s in enumerate(states)}
n = len(states)

i = trans['state'].map(state_idx).to_numpy()
j = trans['next_state'].map(state_idx).to_numpy()
counts = np.zeros((n, n))
np.add.at(counts, (i, j), 1)

row_sums = counts.sum(axis=1, keepdims=True)
P = np.divide(counts, row_sums, out=np.zeros_like(counts), where=row_sums > 0)

P_df = pd.DataFrame(P, index=states, columns=states)

# %%
cur_down = np.array([s[0] for s in states])

agg = np.zeros((4, 4))
for a in range(1, 5):
    rows = np.where(cur_down == a)[0]
    if len(rows) == 0:
        continue
    sub = counts[rows]                     
    for b in range(1, 5):
        cols = np.where(cur_down == b)[0]
        agg[a-1, b-1] = sub[:, cols].sum()

agg_P = agg / agg.sum(axis=1, keepdims=True)  

fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(agg_P, cmap='Blues', vmin=0, vmax=1)
ax.set_xticks(range(4)); ax.set_xticklabels(['1st', '2nd', '3rd', '4th'])
ax.set_yticks(range(4)); ax.set_yticklabels(['1st', '2nd', '3rd', '4th'])
ax.set_xlabel('Next down'); ax.set_ylabel('Current down')
ax.set_title('Down-to-Down Transition Probability')
for i in range(4):
    for j in range(4):
        ax.text(j, i, f'{agg_P[i,j]:.2f}', ha='center', va='center',
                color='white' if agg_P[i,j] > 0.5 else 'black')
fig.colorbar(im, ax=ax, label='Probability')
plt.tight_layout()
plt.show()
